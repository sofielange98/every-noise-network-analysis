# %% [markdown]
# # Project Proposal
#
# Student Name: __Sofia Lange___
#
#
# Group Members: __Srirachan Reddi Varra__ (up to 2 others)
#
# **If you are working in a group, you should EACH submit a copy of your proposal.  The copies may be identical.**

# %% [markdown]
# The dataset has been derived from: http://everynoise.com/
#
# We have attached the notebook which generated the dataset, it is titled EveryNoiseScraper.ipynb

# %%
import pandas as pd 
df_all_genres = pd.read_csv('all_genres.csv')
df_school_genres = pd.read_csv('school_genres.csv')
df_all_genres.head()
# Out:
#    Unnamed: 0               GENRE  \
# 0           0     backgroundmusic
# 1           1  classicmoroccanpop
# 2           2       orthodoxchant
# 3           3                 tar
# 4           4              reggae
#
#                                           SIM_GENRES  \
# 0  ['reiki', 'calminginstrumental', 'yoga', 'back...
# 1  ['bluesrock', 'andalusianclassical', 'chaabima...
# 2  ['universitychoir', 'polishchoir', 'ukrainianc...
# 3  ['oud', 'persiantraditional', 'bansuri', 'tar'...
# 4  ['dancehall', 'brazilianreggae', 'skarevival',...
#
#                                          SIM_WEIGHTS  \
# 0  ['103', '120', '101', '240', '102', '125', '11...
# 1  ['103', '107', '109', '100', '102', '103', '10...
# 2  ['102', '105', '107', '104', '106', '240', '10...
# 3  ['106', '120', '101', '240', '103', '113', '10...
# 4  ['109', '105', '114', '101', '100', '127', '11...
#
#                                           OPP_GENRES  \
# 0  ['mahraganat', 'divahouse', 'oldschoolukhiphop...
# 1  ['shiverpop', 'gravewave', 'tassieindie', 'est...
# 2  ['sambass', 'funkybreaks', 'hardbass', 'hardco...
# 3  ['happyhardcore', 'aggrotech', 'nightcore', 'b...
# 4  ['brazilianlo-firock', 'martialindustrial', 'p...
#
#                                          OPP_WEIGHTS  \
# 0  ['160', '100', '121', '110', '135', '136', '12...
# 1  ['112', '112', '105', '102', '124', '100', '16...
# 2  ['107', '110', '158', '100', '119', '111', '10...
# 3  ['109', '107', '127', '114', '115', '120', '12...
# 4  ['106', '107', '155', '121', '160', '108', '14...
#
#                                          REL_ARTISTS  \
# 0  ['NoemiNucci', 'JuditheAbelsen', 'FabienneWill...
# 1  ['HajHusseinToulali', 'AbdelhadiBelkheyat', 'H...
# 2  ['LegeArtis', 'PeterMichaelides', 'CapellaGreg...
# 3  ['KiyarashSaket', 'YusefForutan', 'HamidMoteba...
# 4  ['TheItals', 'MykalRose', 'JohnnieClark', 'Asw...
#
#                                       ARTIST_WEIGHTS  \
# 0  ['113', '117', '106', '131', '109', '115', '11...
# 1  ['102', '103', '103', '108', '108', '102', '10...
# 2  ['114', '100', '160', '127', '115', '115', '10...
# 3  ['100', '100', '111', '100', '100', '100', '10...
# 4  ['101', '102', '100', '105', '101', '105', '10...
#
#                                          SPOTIFY_URL
# 0  https://open.spotify.com/user/thesoundsofspoti...
# 1  https://open.spotify.com/user/thesoundsofspoti...
# 2  https://open.spotify.com/user/thesoundsofspoti...
# 3  https://open.spotify.com/user/thesoundsofspoti...
# 4  https://open.spotify.com/user/thesoundsofspoti...

# %%
df_school_genres.head()
# Out:
#    Unnamed: 0                                  SCHOOL  \
# 0           0  Texas A & M University-College Station
# 1           1       The University of Texas at Austin
# 2           2       Ohio State University-Main Campus
# 3           3           University of Central Florida
# 4           4          Arizona State University-Tempe
#
#                                               GENRES  \
# 0  ['reddirt', 'outlawcountry', 'texascountry', '...
# 1  ['modernrock', 'indiepop', 'pop', 'indiepoptim...
# 2  ['pop', 'indiepoptimism', 'modernrock', 'indie...
# 3  ['pop', 'poprap', 'rap', 'hiphop', 'electrohou...
# 4  ['edm', 'electrohouse', 'pop', 'electronictrap...
#
#                                        PLAYLIST_LINK
# 0  https://embed.spotify.com/?uri=spotify:playlis...
# 1  https://embed.spotify.com/?uri=spotify:playlis...
# 2  https://embed.spotify.com/?uri=spotify:playlis...
# 3  https://embed.spotify.com/?uri=spotify:playlis...
# 4  https://embed.spotify.com/?uri=spotify:playlis...

# %% [markdown]
# ## Questions of Interest
#
# What is the community structure of subgenres across Spotify? How are communities assembled with various community detection / formation
# algorithms such as AGM, BigCLAM, Spectral Graph Partitioning, Graph Laplacian and Modularity Maximization? In addition while community
# detection algorithms can show relationships between genres, how would other metric / metadata based methods find communities? How are artists
# distributed across the subgenre graph? What are their primary features that categorize a subgenre?
#
# ## Description of everynoise.com, and the dataset we scraped from there.
#
# The website is a collection of 3,652 (and increasing) subgenres of music across
# Spotify along with several other interesting lists such as one for the top genres of
# over 2000 universities across the globe. Each genre links to a page where the user
# can open a playlist for that genre through Spotify and listen to example tracks that
# characterize that genre. The dataset expands to the Spotify playlists themselves,
# where their API can be used to gather information about the playlist and audio
# features the songs themselves. Each subgenre has a table of related subgenres,
# and opposite subgenres as well as example artists whose work heavily fits into the
# genre.
# We used python and BeautifulSoup to scrape our initial dataset from this website. It includes, for each subgenre, the related subgenres, the subgenres which are deemed the "farthest away" from them, as well as that subgenres related artists. Furthermore, we collected the size of the elements referring to these entities because the website sizes elements according to how related they are (or not related), to possibly use as weights for the edges.
# We also generated the dataset called "school_genres" using the every school add on at http://everynoise.com/everyschool.cgi. We got all schools in the USA and the most popular genres for that school, and we also collected the links to the related spotify playlists for that school in order to gather data about music features. In addition those related genres have weights that are displayed by the font size, so that information was scraped from the website, so for each genre's related genres there is a list of weights as well. This will provide an interesting weighted graph.
#
# ## Methods of Analysis
#
# Finding community structure can be done with several algorithms such as AGM, BigCLAM,
# Spectral Graph Partitioning, Graph Laplacian, and Modularity Maximization. In addition to this
# each song has a set of audio features $\{key,mode,time-signature,acousticness,etc..\}$. With
# this set of features we can construct a vector for each song and get averages for the subgenre
# playlists. Generes could then be generated using clustering algorithms like as GMM and K-Means.
# In addition to the exploration of music subgenres *everynoise* provides a list of the top genres
# for each over 2000 universities. This can be analyzed by using graphical orderings/embeddings
# to find the ordering of top genres of across universities in United States. This ordering can
# be constructed with page rank and the SpringRank Hamiltonian.
# The hypothesis is that the different community detection algorithms will in general find the majority of same communities with only little outliers and edge cases that will vary between each of the 5 methods.  The analysis will use Python and specifically pre-constructed network packages such as NetworkX and ideally graph-tool (for it's performance).

# %%
import networkx as nx

G = nx.Graph()
import ast
set_genres = set()
for idx, row in df_all_genres.iterrows():
    G.add_node(row['GENRE'])
    others = ast.literal_eval(row['SIM_GENRES'])
    weights = ast.literal_eval(row['SIM_WEIGHTS'])
    set_genres.add(row['GENRE'])
    set_genres.update(set(list(others)))
    if len(others) > 0:
        edges = [(row['GENRE'], others[i], int(weights[i])) for i in range(len(others))]
    G.add_weighted_edges_from(edges)
    if idx == 200:
        break
print(set_genres)
# Out:
# {'bregaromantico', 'deeppopemo', 'deepgothicpost-punk', 'atmosphericsludge', 'celticmetal', 'alabamaindie', 'chamberpop', 'swedishtechno', 'experimentaltechno', 'danishfolk', 'jamgrass', 'italiancontemporaryclassical', 'frenchrock', 'nursery', 'pinoypraise', 'indonesianpost-hardcore', 'chutney', 'indiefolk', 'anti-folk', 'shimmerpop', 'cabaret', 'austrianhiphop', 'entehno', 'deephardcorepunk', 'dutchurban', 'skacatala', "muzikal'yeladim", 'emocore', 'turkishpop', 'lesen', 'neurostep', 'gqom', 'ukamericana', 'mathrock', 'danspunk', 'portugueseindie', 'singaporeanmetal', 'indianedm', 'dubreggae', 'louisianametal', 'melancholia', 'australianpost-hardcore', 'deepneo-synthpop', 'canzonenapoletana', 'ostrock', 'nugaze', 'middleearth', 'jazzblues', 'classicrussianrock', 'botswanapop', 'appalachianfolk', 'brazilianjazz', 'salsacolombiana', 'zouglou', 'deepswedishrock', 'serbianmetal', 'bowpop', 'deepambient', 'minneapolispunk', 'classicturkishpop', 'banjo', 'raptunisien', 'swedishdoommetal', 'grunge', 'griot', 'outlawcountry', 'voidgaze', 'anthememo', 'romeindie', 'puertoricanrock', 'swedishblackmetal', 'polishreggae', 'electroclash', 'hauntology', 'slovakrock', 'icelandicpop', 'israelirock', 'osharekei', 'argentinehardcore', 'tibetanpop', 'sardiniaindie', 'hardingfele', 'futurefunk', 'miamimetal', 'halloween', 'sinhalarap', 'canadianclassical', 'baselindie', 'midwestemo', 'mexicanclassical', 'christlicherrap', 'reggae', 'post-metal', 'grooveroom', 'australianchoir', 'russianindie', 'classicrock', 'vietnamesepop', 'neo-synthpop', 'turinindie', 'chicagopunk', 'luxembourgianindie', 'israelijazz', 'southafricanpop', 'swisshiphop', 'manitobaindie', 'nwocr', 'irishcontemporaryclassical', 'rawblackmetal', 'guidedmeditation', 'etherealgothic', 'southernamericana', 'lithuanianhiphop', 'grungepop', 'post-rock', 'okcindie', 'spanishbaroque', 'austro-germanmodernism', 'hiphouse', 'newwavepop', 'punkska', 'merenguetipico', 'oceaniasoundtrack', 'powermetal', 'swedishmetal', 'rajasthanipop', 'cumbiasonidera', 'norwegianchoir', 'vintagehollywood', 'cumbia', 'normanokindie', 'minimaltechno', 'afropsych', 'nzhiphop', 'alternativehiphop', 'hungariancontemporaryclassical', 'norteno-sax', 'polishtrap', 'dreamo', 'idolrock', 'slovenianrock', 'swedishfiddle', 'greekmetal', 'brazilianccm', 'albuquerqueindie', 'basstrap', 'westafricanjazz', 'swedishpop', 'finnishdeathmetal', 'tamilpop', 'slovenianelectronic', 'socalpoppunk', 'theme', 'portugueseexperimental', 'alt-idol', 'pinoyr&b', 'classicalflute', 'zen', 'polishpost-rock', 'dutchhiphop', 'albertahiphop', 'spanishpsychedelicrock', 'warmdrone', 'skamexicano', 'chineseexperimental', 'experimentalelectronic', 'progressivetrancehouse', 'slashpunk', 'southafricanpunk', 'hungarianpop', 'swedishhardrock', 'sinaloaindie', 'rapmarseille', 'polishelectronica', 'meridaindie', 'russianpop', 'electronicacristiana', 'swedishurban', 'batonrougerap', 'freakfolk', 'gbvfi', 'melodicdeathcore', 'manguebit', 'bretonfolk', 'dragspel', 'indietico', 'danishelectropop', 'rockabilly', 'irishelectronic', 'blackenedcrust', 'canadianmetalcore', 'newzealandclassical', 'oktoberfest', 'symphonicmetal', 'funkevangelico', 'funkrock', 'kundiman', 'spanishblackmetal', 'hamburgelectronic', 'africanexperimental', 'tavern', 'intelligentdancemusic', 'irishclassical', 'glitchhop', 'italianska', 'deepsoundtrack', 'serbianfolk', 'j-acoustic', 'deeplatinalternative', 'popurbaine', 'newweirdamerica', 'quebecindie', 'oklahomacountry', 'canadianelectropop', 'carnaticinstrumental', 'deepbrazilianpop', 'canadianpop', 'j-poprock', 'shoegaze', 'brazilianemo', 'deepvocalhouse', 'segamauricien', 'tajikpop', 'modernblues', 'pakistaniindie', 'tone', 'southernsoulblues', 'bongoflava', 'earlyromanticera', 'newwaveofglammetal', 'indonesianpop', 'glasgowindie', 'lo-fi', 'speedgarage', 'slovenianpop', 'slavicmetal', 'thall', 'trapcatala', 'italiansoundtrack', 'scottishindierock', 'argentinepunk', 'spacerock', 'colombianrock', 'italianalternative', 'neor&b', 'briti ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300

fig, ax = plt.subplots(1, figsize = (16,9))

pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, nodelist = list(set_genres), node_size = 20, alpha = 1)
nx.draw_networkx_edges(G, pos, width = 1.0, alpha = 1, connectionstyle = 'arc3, rad=1')
labels = nx.draw_networkx_labels(G, pos, font_size = 3)

ax.axis('off')
# plt.show()
fig.savefig('./images/spring_layout_subgenres.pdf', bbox_inches='tight')
# Out:
# /home/sri/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
c = list(nx.algorithms.community.modularity_max.greedy_modularity_communities(G))

# %%
# print(len(set_genres))
# Out:
# 3862

# %%
print(len(c))
print(c[10])
# Out:
# 13
# [frozenset({'bregaromantico', 'deepgothicpost-punk', 'celticmetal', 'alabamaindie', 'chamberpop', 'swedishtechno', 'danishfolk', 'jamgrass', 'italiancontemporaryclassical', 'chutney', 'anti-folk', 'indiefolk', 'cabaret', 'austrianhiphop', 'deephardcorepunk', 'emocore', 'turkishpop', 'gqom', 'portugueseindie', 'indianedm', 'louisianametal', 'ostrock', 'australianpost-hardcore', 'canzonenapoletana', 'jazzblues', 'salsacolombiana', 'nugaze', 'appalachianfolk', 'bowpop', 'minneapolispunk', 'classicturkishpop', 'raptunisien', 'swedishdoommetal', 'griot', 'anthememo', 'swedishblackmetal', 'electroclash', 'hauntology', 'slovakrock', 'israelirock', 'osharekei', 'mexicanclassical', 'christlicherrap', 'post-metal', 'vietnamesepop', 'neo-synthpop', 'turinindie', 'israelijazz', 'southafricanpop', 'swisshiphop', 'irishcontemporaryclassical', 'guidedmeditation', 'southernamericana', 'grungepop', 'post-rock', 'okcindie', 'spanishbaroque', 'austro-germanmodernism', 'newwavepop', 'oceaniasoundtrack', 'rajasthanipop', 'norwegianchoir', 'vintagehollywood', 'normanokindie', 'minimaltechno', 'nzhiphop', 'polishtrap', 'dreamo', 'idolrock', 'greekmetal', 'albuquerqueindie', 'basstrap', 'westafricanjazz', 'swedishpop', 'finnishdeathmetal', 'socalpoppunk', 'pinoyr&b', 'classicalflute', 'slashpunk', 'southafricanpunk', 'swedishhardrock', 'rapmarseille', 'polishelectronica', 'electronicacristiana', 'batonrougerap', 'swedishurban', 'gbvfi', 'melodicdeathcore', 'manguebit', 'newzealandclassical', 'oktoberfest', 'symphonicmetal', 'hamburgelectronic', 'intelligentdancemusic', 'italianska', 'glitchhop', 'popurbaine', 'oklahomacountry', 'shoegaze', 'brazilianemo', 'modernblues', 'pakistaniindie', 'southernsoulblues', 'bongoflava', 'earlyromanticera', 'glasgowindie', 'slovenianpop', 'slavicmetal', 'trapcatala', 'spacerock', 'italianalternative', 'metalcore', 'dutchrock', 'hardalternative', 'dutchpunk', 'rockchapin', 'deepfolkmetal', 'zouk', 'wave', 'ritmokombina', 'sandalwood', 'sami', 'deathmetal', 'orchestra', 'ukdub', 'deepgroovehouse', 'blackdeath', 'radiosymphony', 'texaspunk', 'galicianrock', 'mexicanrock', 'finnishindie', 'guineanpop', 'polishalternativerock', 'trapmexicano', 'j-pixie', 'britishexperimental', 'deeporgcore', 'slovenianrock', 'skaespanol', 'instrumentalbluegrass', 'estonianpop', 'burystedmundsindie', 'japaneser&b', 'ambientblackmetal', 'gospelblues', 'classicaltuba', 'finnishdoommetal', 'brazilianedm', 'alabamametal', 'folk-pop', 'deepsoftrock', 'folkloreboliviano', 'experimentalblackmetal', 'sci-fimetal', 'triphop', 'melodicmetalcore', 'groovemetal', 'argentinejazz', 'indonesianedm', 'folklorevenezolano', 'japanesealternativerock', 'hollywood', 'rocksteady', 'industrialblackmetal', 'danishchoir', 'technicalblackmetal', 'jamband', 'portlandhiphop', 'germanreggae', 'classiciskelma', 'portuguesepop', 'paracana', 'belarusianrock', 'dronefolk', 'norwegianmetal', 'flemishfolk', 'electropowerpop', 'muzicacrestina', 'romantico', 'doujin', 'sefardi', 'reiki', 'scorecore', 'highlife', 'christelijk', 'japaneseclassicalperformance', 'polishtechno', 'mexicanmetal', 'welshfolk', 'blues-rockguitar', 'melodicprogressivemetal', 'israelipop', 'deeptechno', 'swissmetal', 'moombahton', 'italianpostpunk', 'modernperformance', 'brazilianska', 'ambeat', 'recorder', 'kashmiripop', 'postmetal', 'cybermetal', 'austrianstonerrock', 'cantautorcatala', 'sodapop', 'noisepunk', 'neworleansfunk', 'ottawaindie', 'finnishblackmetal', 'vintagechinesepop', 'deltablues', 'darkjazz', 'earlymusicchoir', 'tico', 'postpunk', 'c64', 'icelandicexperimental', 'uyghurfolk', 'parody', 'divahouse', 'israeliclassical', 'japanesesoundtrack', 'kiwirock', 'panamanianrock', 'earlymusicensemble', 'puertoricanmetal', 'neoclassical', 'reggaetonflow', 'cocuksarkilari', 'latinalternative', 'classicitalianpop', 'westvirginiaindie', 'minimalwave', 'dhrupad', 'riotgrrrl', 'fidgethouse', 'deepnewamericana', 'ukrainianblackmetal', 'neuedeutschewelle', 'tarantella', 'schoolchoir', 'focus', 'neo-clas ...
