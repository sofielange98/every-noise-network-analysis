# %%
# Imports
import numpy as np
import pandas as pd 
import networkx as nx
from networkx.algorithms import community
import community


import ast
import matplotlib.pyplot as plt
from joblib import Parallel, delayed


from collections import defaultdict
from scipy.cluster import hierarchy
from scipy.spatial import distance
from networkx.drawing.nx_agraph import graphviz_layout

# %%
df_allG = pd.read_csv('all_genres.csv')
df_allG = df_allG.set_index('GENRE')
df_allG.head()
# Out:
#                     Unnamed: 0  \
# GENRE
# backgroundmusic              0
# classicmoroccanpop           1
# orthodoxchant                2
# tar                          3
# reggae                       4
#
#                                                            SIM_GENRES  \
# GENRE
# backgroundmusic     ['reiki', 'calminginstrumental', 'yoga', 'back...
# classicmoroccanpop  ['bluesrock', 'andalusianclassical', 'chaabima...
# orthodoxchant       ['universitychoir', 'polishchoir', 'ukrainianc...
# tar                 ['oud', 'persiantraditional', 'bansuri', 'tar'...
# reggae              ['dancehall', 'brazilianreggae', 'skarevival',...
#
#                                                           SIM_WEIGHTS  \
# GENRE
# backgroundmusic     ['103', '120', '101', '240', '102', '125', '11...
# classicmoroccanpop  ['103', '107', '109', '100', '102', '103', '10...
# orthodoxchant       ['102', '105', '107', '104', '106', '240', '10...
# tar                 ['106', '120', '101', '240', '103', '113', '10...
# reggae              ['109', '105', '114', '101', '100', '127', '11...
#
#                                                            OPP_GENRES  \
# GENRE
# backgroundmusic     ['mahraganat', 'divahouse', 'oldschoolukhiphop...
# classicmoroccanpop  ['shiverpop', 'gravewave', 'tassieindie', 'est...
# orthodoxchant       ['sambass', 'funkybreaks', 'hardbass', 'hardco...
# tar                 ['happyhardcore', 'aggrotech', 'nightcore', 'b...
# reggae              ['brazilianlo-firock', 'martialindustrial', 'p...
#
#                                                           OPP_WEIGHTS  \
# GENRE
# backgroundmusic     ['160', '100', '121', '110', '135', '136', '12...
# classicmoroccanpop  ['112', '112', '105', '102', '124', '100', '16...
# orthodoxchant       ['107', '110', '158', '100', '119', '111', '10...
# tar                 ['109', '107', '127', '114', '115', '120', '12...
# reggae              ['106', '107', '155', '121', '160', '108', '14...
#
#                                                           REL_ARTISTS  \
# GENRE
# backgroundmusic     ['NoemiNucci', 'JuditheAbelsen', 'FabienneWill...
# classicmoroccanpop  ['HajHusseinToulali', 'AbdelhadiBelkheyat', 'H...
# orthodoxchant       ['LegeArtis', 'PeterMichaelides', 'CapellaGreg...
# tar                 ['KiyarashSaket', 'YusefForutan', 'HamidMoteba...
# reggae              ['TheItals', 'MykalRose', 'JohnnieClark', 'Asw...
#
#                                                        ARTIST_WEIGHTS  \
# GENRE
# backgroundmusic     ['113', '117', '106', '131', '109', '115', '11...
# classicmoroccanpop  ['102', '103', '103', '108', '108', '102', '10...
# orthodoxchant       ['114', '100', '160', '127', '115', '115', '10...
# tar                 ['100', '100', '111', '100', '100', '100', '10...
# reggae              ['101', '102', '100', '105', '101', '105', '10...
#
#                                                           SPOTIFY_URL
# GENRE
# backgroundmusic     https://open.spotify.com/user/thesoundsofspoti...
# classicmoroccanpop  https://open.spotify.com/user/thesoundsofspoti...
# orthodoxchant       https://open.spotify.com/user/thesoundsofspoti...
# tar                 https://open.spotify.com/user/thesoundsofspoti...
# reggae              https://open.spotify.com/user/thesoundsofspoti...

# %%
popular_genres = pd.read_csv('top_genres_scored.csv', header = None)
popular_genres.head()
# Out:
#                 0       1
# 0             pop  1885.0
# 1          poprap  1864.0
# 2          hiphop  1557.0
# 3             rap  1511.0
# 4  southernhiphop  1196.0

# %%
df_allG = df_allG.loc[popular_genres[0].values]

# %%
len(df_allG)
# Out:
# 75

# %%
'''
df: Dataframe
support: The minimum number of connections a node must have to be incorporated into the set of genres

Useful for checking the genres that have over <support> connections.
'''
def set_genre(df, support: int = -1):
    set_genres = set()
    for idx, row in df.iterrows():
        connections = ast.literal_eval(row['SIM_GENRES'])
        
         # Only add the (node,edges) into the set if the number of connections is greater than the support
        if len(connections) > support:
            set_genres.add(row['GENRE'])
            set_genres.update(connections)
    return (support, set_genres)

'''
df: Dataframe
support: The minimum number of connections a node must have to be incorporated into the graph
n: The number of rows to traverse on the Dataframe (only useful for testing)
'''
def generate_G(df, pop_nodes, n = 5000):
    G = nx.Graph()
    for idx, row in df.iterrows():
        connections = ast.literal_eval(row['SIM_GENRES'])
        weights = ast.literal_eval(row['SIM_WEIGHTS'])
        
        # Only add the (node,edges) if the number of connections is greater than the support
        G.add_node(idx)
        edges = [(idx, connections[i], int(weights[i])) for i in range(len(connections)) if connections[i] in pop_nodes]
        G.add_weighted_edges_from(edges)
            
        # Useful if you only need a small sample (for testing mainly)
        if idx == n:
            break
    return G

def plot_network(G, set_genres):
    plt.rcParams['figure.dpi'] = 300

    fig, ax = plt.subplots(1, figsize = (16,9))

    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, nodelist = list(set_genres), node_size = 20, alpha = 1)
    nx.draw_networkx_edges(G, pos, width = 1.0, alpha = 1, connectionstyle = 'arc3, rad=1')
#     labels = nx.draw_networkx_labels(G, pos, font_size = 3)

    ax.axis('off')
    plt.show()
#     fig.savefig('./images/spring_layout_subgenres.pdf', bbox_inches='tight')

# %%
G1 = generate_G(df_allG, popular_genres[0].values, 2)

# %%
louvian_mod_max = community.best_partition(G1, partition=None, weight = 'weight', resolution=1.0, randomize = None, random_state = None)

# %%
louvian_mod_max
# Out:
# {'pop': 0,
#  'indiepoptimism': 1,
#  'hiphop': 0,
#  'tropical': 2,
#  'electrohouse': 3,
#  'southernhiphop': 0,
#  'urbancontemporary': 0,
#  'poprap': 0,
#  'rap': 0,
#  'latin': 2,
#  'edm': 3,
#  'electropop': 1,
#  'dancepop': 0,
#  'dirtysouthrap': 0,
#  'undergroundhiphop': 0,
#  'atlhiphop': 0,
#  'melodicrap': 0,
#  'indiepoprap': 0,
#  'gangsterrap': 0,
#  'hyphy': 0,
#  'westcoasttrap': 0,
#  'vaportrap': 0,
#  'calirap': 0,
#  'escaperoom': 1,
#  'vaporsoul': 1,
#  'modernrock': 1,
#  'indiepop': 1,
#  'chamberpop': 1,
#  'indietronica': 1,
#  'popedm': 3,
#  'artpop': 1,
#  'indiesoul': 1,
#  'stompandholler': 1,
#  'indierock': 1,
#  'indiefolk': 1,
#  'alternativeemo': 4,
#  'emo': 4,
#  'alternativerb': 1,
#  'country': 5,
#  'moderncountryrock': 5,
#  'countrypop': 5,
#  'texascountry': 5,
#  'contemporarycountry': 5,
#  'countryrock': 5,
#  'countryroad': 5,
#  'outlawcountry': 5,
#  'reddirt': 5,
#  'indierb': 1,
#  'zapstep': 3,
#  'electronictrap': 3,
#  'vaportwitch': 3,
#  'brostep': 3,
#  'christianpop': 6,
#  'indiecoustica': 6,
#  'christianalternativerock': 6,
#  'anthemworship': 6,
#  'christianuplift': 6,
#  'rootsworship': 6,
#  'christianmusic': 6,
#  'ccm': 6,
#  'worldworship': 6,
#  'worship': 6,
#  'deepccm': 6,
#  'deeppoprb': 0,
#  'folkpop': 1,
#  'indiegaragerock': 1,
#  'rootsamericana': 5,
#  'soul': 0,
#  'reggaerock': 0,
#  'regionalmexicanpop': 2,
#  'norteno': 2,
#  'corrido': 2,
#  'rb': 0,
#  'latinhiphop': 2,
#  'traplatino': 2}

# %%
pd.Series(louvian_mod_max).to_csv('genre_louv_cat.csv')
# Out:
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
